# %% [markdown]
# <a href="https://colab.research.google.com/github/Akeem-A/Akeem-A/blob/main/Task_1_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Linking Google Drive to Collab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importing the "sales" data from MyDrive
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', index_col = 0)
print(df)
# Out:
#                          Region  No_of_Orders      Profit       Sales
# Market
# Africa           Western Africa           251  -12,901.51   78,476.06
# Africa          Southern Africa            85   11,768.58   51,319.50
# Africa             North Africa           182   21,643.08   86,698.89
# Africa           Eastern Africa           110    8,013.04   44,182.60
# Africa           Central Africa           103   15,606.30   61,689.99
# Asia Pacific       Western Asia           382  -16,766.90  124,312.24
# Asia Pacific      Southern Asia           469   67,998.76  351,806.60
# Asia Pacific  Southeastern Asia           533   20,948.84  329,751.38
# Asia Pacific            Oceania           646   54,734.02  408,002.98
# Asia Pacific       Eastern Asia           414   72,805.10  315,390.77
# Asia Pacific       Central Asia            37   -2,649.76    8,190.74
# Europe           Western Europe           964   82,091.27  656,637.14
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', index_col = 0)

display(df)
# Out:
#                          Region  No_of_Orders      Profit       Sales
# Market
# Africa           Western Africa           251  -12,901.51   78,476.06
# Africa          Southern Africa            85   11,768.58   51,319.50
# Africa             North Africa           182   21,643.08   86,698.89
# Africa           Eastern Africa           110    8,013.04   44,182.60
# Africa           Central Africa           103   15,606.30   61,689.99
# Asia Pacific       Western Asia           382  -16,766.90  124,312.24
# Asia Pacific      Southern Asia           469   67,998.76  351,806.60
# Asia Pacific  Southeastern Asia           533   20,948.84  329,751.38
# Asia Pacific            Oceania           646   54,734.02  408,002.98
# Asia Pacific       Eastern Asia           414   72,805.10  315,390.77
# Asia Pacific       Central Asia            37   -2,649.76    8,190.74
# Europe           Western Europe           964   82,091.27  656,637.14
# ...

# %%
#Checking for Missing Values in the sales data
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', index_col = 0)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, Africa to USCA
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Region        23 non-null     object
#  1   No_of_Orders  23 non-null     int64
#  2   Profit        23 non-null     object
#  3   Sales         23 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 920.0+ bytes
# None

# %%
#Checking if there is any missing values
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', index_col = 0)
df.notnull()
# Out:
#               Region  No_of_Orders  Profit  Sales
# Market
# Africa          True          True    True   True
# Africa          True          True    True   True
# Africa          True          True    True   True
# Africa          True          True    True   True
# Africa          True          True    True   True
# Asia Pacific    True          True    True   True
# Asia Pacific    True          True    True   True
# Asia Pacific    True          True    True   True
# Asia Pacific    True          True    True   True
# Asia Pacific    True          True    True   True
# Asia Pacific    True          True    True   True
# Europe          True          True    True   True
# Europe          True          True    True   True
# Europe          True          True    True   True
# Europe          True          True    True   True
# LATAM           True          True    True   True
# LATAM           True          True    True   True
# LATAM           True          True    True   True
# ...

# %%
#Seeting the First 2 columns as Indexs
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', header=[1], index_col =[1])
print(df)
# Out:
#                          Africa  251  -12,901.51   78,476.06
# Western Africa
# Southern Africa          Africa   85   11,768.58   51,319.50
# North Africa             Africa  182   21,643.08   86,698.89
# Eastern Africa           Africa  110    8,013.04   44,182.60
# Central Africa           Africa  103   15,606.30   61,689.99
# Western Asia       Asia Pacific  382  -16,766.90  124,312.24
# Southern Asia      Asia Pacific  469   67,998.76  351,806.60
# Southeastern Asia  Asia Pacific  533   20,948.84  329,751.38
# Oceania            Asia Pacific  646   54,734.02  408,002.98
# Eastern Asia       Asia Pacific  414   72,805.10  315,390.77
# Central Asia       Asia Pacific   37   -2,649.76    8,190.74
# Western Europe           Europe  964   82,091.27  656,637.14
# Southern Europe          Europe  338   18,911.49  215,703.93
# Northern Europe          Europe  367   43,237.44  252,969.09
# Eastern Europe           Europe  241   25,050.69  108,258.93
# ...

# %%
# Showing the First 3 rows & Last 3 rows of the sales data
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', index_col = 0)
display(df.head(3), df.tail(3))
# Out:
#                  Region  No_of_Orders      Profit      Sales
# Market
# Africa   Western Africa           251  -12,901.51  78,476.06
# Africa  Southern Africa            85   11,768.58  51,319.50
# Africa     North Africa           182   21,643.08  86,698.89
#             Region  No_of_Orders     Profit       Sales
# Market
# USCA    Eastern US           443  47,462.04  264,973.98
# USCA    Central US           356  33,697.43  170,416.31
# USCA        Canada            49   7,246.62   26,298.81

# %%
#Displaying the Statistical information of the Dataframe
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', index_col = 0)
df.describe()
# Out:
#        No_of_Orders
# count     23.000000
# mean     366.478261
# std      246.590361
# min       37.000000
# 25%      211.500000
# 50%      356.000000
# 75%      479.500000
# max      964.000000

# %%
#Displaying the sales column as a series
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', index_col = 0)
pd.Series(df['Sales'])
# Out:
# Market
# Africa           78,476.06
# Africa           51,319.50
# Africa           86,698.89
# Africa           44,182.60
# Africa           61,689.99
# Asia Pacific    124,312.24
# Asia Pacific    351,806.60
# Asia Pacific    329,751.38
# Asia Pacific    408,002.98
# Asia Pacific    315,390.77
# Asia Pacific      8,190.74
# Europe          656,637.14
# Europe          215,703.93
# Europe          252,969.09
# Europe          108,258.93
# LATAM           210,710.49
# LATAM           461,670.28
# LATAM           116,333.05
# USCA            251,991.83
# USCA            148,771.91
# USCA            264,973.98
# USCA            170,416.31
# USCA             26,298.81
# Name: Sales, dtype: object

# %%
#Displaying the "Sales" & "Profit" Column as a dataframe
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', index_col = 0)
SP = df[['Sales','Profit']]
print(SP)
# Out:
#                    Sales      Profit
# Market
# Africa         78,476.06  -12,901.51
# Africa         51,319.50   11,768.58
# Africa         86,698.89   21,643.08
# Africa         44,182.60    8,013.04
# Africa         61,689.99   15,606.30
# Asia Pacific  124,312.24  -16,766.90
# Asia Pacific  351,806.60   67,998.76
# Asia Pacific  329,751.38   20,948.84
# Asia Pacific  408,002.98   54,734.02
# Asia Pacific  315,390.77   72,805.10
# Asia Pacific    8,190.74   -2,649.76
# Europe        656,637.14   82,091.27
# Europe        215,703.93   18,911.49
# Europe        252,969.09   43,237.44
# Europe        108,258.93   25,050.69
# LATAM         210,710.49   12,377.59
# LATAM         461,670.28   74,679.54
# LATAM         116,333.05   13,529.59
# USCA          251,991.83   44,303.65
# USCA          148,771.91   19,991.83
# USCA          264,973.98   47,462.04
# USCA          170,416.31   33,697.43
# USCA           26,298.81    7,246.62

# %%
#Showing the Data for "Southern Asia" only
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', index_col = 0)
print(df.iloc[6])
# Out:
# Region          Southern Asia
# No_of_Orders              469
# Profit              67,998.76
# Sales              351,806.60
# Name: Asia Pacific, dtype: object

# %%
#Showing the "Sales & "Profit" data of "Western Africa", "Southern Africa", "North Africa"
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/sales.csv', index_col = 0)
SP = df[['Region','Sales','Profit']]
print(SP.iloc[0:3])
# Out:
#                  Region      Sales      Profit
# Market
# Africa   Western Africa  78,476.06  -12,901.51
# Africa  Southern Africa  51,319.50   11,768.58
# Africa     North Africa  86,698.89   21,643.08
